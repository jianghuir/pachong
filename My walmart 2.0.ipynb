# %%
from urllib.request import Request, urlopen
from selenium import webdriver
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import numpy as np
import time
import random
import os
import json

# %%
class MyWalmart():
    def get_soup(self, url):
        """
        This function get the beautifulsoup object of a webpage.

        Args:
            url (str): the link string of webpage

        Returns:
            soup (obj): beautifulsoup object
        """
        request = Request(url, headers={'User-Agent': 'Resistance is futile'})
        response = urlopen(request)
        return BeautifulSoup(response, "html.parser")
    
    def get_product_links_from_page(self, url):
        """
        This function gets the links of the product on the product search page page.

        Args:
            url (str): link to joblist page

        Returns:
            links (list): list of links to individual products of the keyword
        """
             
        soup = self.get_soup(url)
        head = "https://www.walmart.com"  
        links = []
        for item in soup.find_all("a", href=True):
            if 'link-identifier=' in str(item) and '/ip/' in str(item):  
                link = item['href']
                links.append(head+link)
        return links
     
    def get_products(self, keyword):
        """
        Args:
            keyword (str): example: 'Christmas tree'

        Returns:
        """
        gap_min = 5 #min sleep time between clicks
        gap_max = 10 #max sleep time between clicks
        
        url = "https://www.walmart.com/search?q="
        keyword_list = keyword.split()
        
        for i in range(len(keyword_list)):
            url+='%20'
            url+=keyword_list[i]    

            #get links individual products with the keyword
        links = self.get_product_links_from_page(url)
        #print(links)
        #get information of individual products
        for link in links:
            gap = np.random.uniform(gap_min,gap_max) 
            time.sleep(gap)
            data = self.get_info_from_product_page(link)

            print(json.dumps(data))
            
    def get_info_from_product_page(self, url):
        """
        This function get info from the webpage of an individual product.

        Args:
            url (str): link to the product webpage

        Returns:
            data (dict): dictionary with keywords: 
                         item, price, link
        """
        soup = self.get_soup(url)
        data = {}
        
        try:
            data['item'] = soup.find('h1', itemprop="name").getText()
            data["price"] = soup.find('span', itemprop="price").getText()
            data["link"] = str(url)
        except:
            pass
        return data

# %%
w = MyWalmart()

# %%
w.get_products('jeans')
# Out:
# {"item": "George Men's Regular Fit Jean", "price": "$10.44", "link": "https://www.walmart.com/ip/George-Men-s-Regular-Fit-Jean/701236486?athbdg=L1600"}
# {"item": "George Men's Regular Fit Jean", "price": "$10.44", "link": "https://www.walmart.com/ip/George-Men-s-Regular-Fit-Jean/974623932?variantFieldId=actual_color"}
# {"item": "George Men's Regular Fit Jean", "price": "$10.44", "link": "https://www.walmart.com/ip/George-Men-s-Regular-Fit-Jean/701236486?variantFieldId=actual_color"}
# {"item": "George Men's Regular Fit Jean", "price": "$10.44", "link": "https://www.walmart.com/ip/George-Men-s-Regular-Fit-Jean/958341066?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans", "price": "$9.88", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans/768337976"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans", "price": "$9.88", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans/961358752?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans", "price": "$9.88", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans/768337976?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans", "price": "$9.88", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans/191885457?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans", "price": "$9.88", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans/236831330?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' Super High Rise Destructed Mom Jeans", "price": "$17.98", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-Super-High-Rise-Destructed-Mom-Jeans/561277790"}
# {"item": "No Boundaries Juniors' Super High Rise Destructed Mom Jeans", "price": "$17.98", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-Super-High-Rise-Destructed-Mom-Jeans/561277790?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' Super High Rise Destructed Mom Jeans", "price": "$17.98", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-Super-High-Rise-Destructed-Mom-Jeans/231376493?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' Super High Rise Destructed Mom Jeans", "price": "$17.98", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-Super-High-Rise-Destructed-Mom-Jeans/327769290?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' Super High Rise Destructed Mom Jeans", "price": "$17.98", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-Super-High-Rise-Destructed-Mom-Jeans/923866420?variantFieldId=actual_color"}
# {"item": "Signature by Levi Strauss & Co. Women's Modern Bootcut Jeans", "price": "$15.00", "link": "https://www.walmart.com/ip/Signature-by-Levi-Strauss-Co-Women-s-Modern-Bootcut-Jeans/558491717?athbdg=L1300"}
# {"item": "Signature by Levi Strauss & Co. Women's Modern Bootcut Jeans", "price": "$15.00", "link": "https://www.walmart.com/ip/Signature-by-Levi-Strauss-Co-Women-s-Modern-Bootcut-Jeans/982912898?variantFieldId=actual_color"}
# {"item": "Signature by Levi Strauss & Co. Women's Modern Bootcut Jeans", "price": "$15.00", "link": "https://www.walmart.com/ip/Signature-by-Levi-Strauss-Co-Women-s-Modern-Bootcut-Jeans/394923196?variantFieldId=actual_color"}
# {"item": "Signature by Levi Strauss & Co. Women's Modern Bootcut Jeans", "price": "$15.00", "link": "https://www.walmart.com/ip/Signature-by-Levi-Strauss-Co-Women-s-Modern-Bootcut-Jeans/379604821?variantFieldId=actual_color"}
# {"item": "Signature by Levi Strauss & Co. Women's Modern Bootcut Jeans", "price": "$15.00", "link": "https://www.walmart.com/ip/Signature-by-Levi-Strauss-Co-Women-s-Modern-Bootcut-Jeans/452785205?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans, 2-Pack", "price": "$17.98", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans-2-Pack/878330925?athbdg=L1600"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans, 2-Pack", "price": "$18.00", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans-2-Pack/499122294?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans, 2-Pack", "price": "$17.98", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans-2-Pack/873936074?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans, 2-Pack", "price": "$17.98", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans-2-Pack/878330925?variantFieldId=actual_color"}
# {"item": "No Boundaries Juniors' High Rise Skinny Jeans, 2-Pack", "price": "$19.76", "link": "https://www.walmart.com/ip/No-Boundaries-Juniors-High-Rise-Skinny-Jeans-2-Pack/237120107?variantFieldId=actual_color"}
# {"item": "George Men's Relaxed Fit Jean", "price": "$12.44", "link": "https://www.walmart.com/ip/George-Men-s-Relaxed-Fit-Jean/150422290?athbdg=L1600"}
# {"item": "George Men's Relaxed Fit Jean", "price": "$12.44", "link": "https://www.walmart.com/ip/George-Men-s-Relaxed-Fit-Jean/116450150?variantFieldId=actual_color"}
# {"item": "George Men's Relaxed Fit Jean", "price": "$12.44", "link": "https://www.walmart.com/ip/George-Men-s-Relaxed-Fit-Jean/359560296?variantFieldId=actual_color"}
# {"item": "George Men's Relaxed Fit Jean", "price": "$12.44", "link": "https://www.walmart.com/ip/George-Men-s-Relaxed-Fit-Jean/150422290?variantFieldId=actual_color"}
# {"item": "Terra & Sky Women's Plus Size Denim Pull on Straight Leg Jean", "price": "$17.97", "link": "https://www.walmart.com/ip/Terra-Sky-Women-s-Plus-Size-Denim-Pull-on-Straight-Leg-Jean/507039690"}
# {"item": "Terra & Sky Women's Plus Size Denim Pull on Straight Leg Jean", "price": "$17.97", "link": "https://www.walmart.com/ip/Terra-Sky-Women-s-Plus-Size-Denim-Pull-on-Straight-Leg-Jean/507039690?variantFieldId=actual_color"}
# {"item": "Terra & Sky Women's Plus Size Denim Pull on Straight Leg Jean", "price": "$17.97", "link": "https://www.walmart.com/ip/Terra-Sky-Women-s-Plus-Size-Denim-Pull-on-Straight-Leg-Jean/430759866?variantFieldId=actual_color"}
# {"item": "Terra & Sky Women's Plus Size Denim Pull on Straight Leg Jean", "price": "$17.97", "link": "https://www.walmart.com/ip/Terra-Sky-Women-s-Plus-Size-Denim-Pull-on-Straight-Leg-Jean/344747735?variantFieldId=actual_color"}
# {"item": "Signature by Levi Strauss & Co. Women's Simply Stretch Shaping Pull-On Super Skinny Jeans", "price": "$24.99", "link": "https://www.walmart.com/ip/Signature-by-Levi-Strauss-Co-Women-s-Simply-Stretch-Shaping-Pull-On-Super-Skinny-Jeans/585195234"}
# {"item": "Signature by Levi Strauss & Co. Women's Simply Stretch Shaping Pull-On Super Skinny Jeans", "price": "$24.94", "link": "https://www.walmart.com/ip/Signature-by-Levi-Strauss-Co-Women-s-Simply-Stretch-Shaping-Pull-On-Super-Skinny-Jeans/452770264?variantFieldId=actual_color"}
# {"item": "Signature by Levi Strauss & Co. Women's Simply Stretch Shaping Pull-On Super Skinny Jeans", "price": "$24.99", "link": "https://www.walmart.com/ip/Signature-by-Levi-Strauss-Co-Women-s-Simply-Stretch-Shaping-Pull-On-Super-Skinny-Jeans/585195234?variantFieldId=actual_color"}
# {"item": "Sofia Jeans by Sofia Vergara Women\u2019s Marisol Bootcut Jeans", "price": "$28.50", "link": "https://www.walmart.com/ip/Sofia-Jeans-by-Sofia-Vergara-Women-s-Marisol-Bootcut-Jeans/835809563?athbdg=L1700"}
# {"item": "Sofia Jeans by Sofia Vergara Women\u2019s Marisol High Rise Bootcut Jeans", "price": "$28.50", "link": "https://www.walmart.com/ip/Sofia-Jeans-by-Sofia-Vergara-Women-s-Marisol-High-Rise-Bootcut-Jeans/309620980?variantFieldId=actual_color"}
# {"item": "Sofia Jeans by Sofia Vergara Women\u2019s Marisol Bootcut Jeans", "price": "$28.50", "link": "https://www.walmart.com/ip/Sofia-Jeans-by-Sofia-Vergara-Women-s-Marisol-Bootcut-Jeans/367171558?variantFieldId=actual_color"}
# {"item": "Sofia Jeans by Sofia Vergara Women\u2019s Marisol Bootcut Jeans", "price": "$28.50", "link": "https://www.walmart.com/ip/Sofia-Jeans-by-Sofia-Vergara-Women-s-Marisol-Bootcut-Jeans/580192209?variantFieldId=actual_color"}
# {"item": "Sofia Jeans by Sofia Vergara Marisol Bootcut Jeans", "price": "$28.50", "link": "https://www.walmart.com/ip/Sofia-Jeans-by-Sofia-Vergara-Marisol-Bootcut-Jeans/201247168?variantFieldId=actual_color"}
# {"item": "Lee Women's Midrise Straight Leg Jean", "price": "$21.94", "link": "https://www.walmart.com/ip/Lee-Women-s-Midrise-Straight-Leg-Jean/178550486"}
# {"item": "Lee Women's Midrise Straight Jean", "price": "$21.94", "link": "https://www.walmart.com/ip/Lee-Women-s-Midrise-Straight-Jean/849178050?variantFieldId=actual_color"}
# {"item": "Lee Women's Midrise Straight Leg Jean", "price": "$21.94", "link": "https://www.walmart.com/ip/Lee-Women-s-Midrise-Straight-Leg-Jean/288602017?variantFieldId=actual_color"}
# {"item": "Lee Women's Midrise Straight Leg Jean", "price": "$21.94", "link": "https://www.walmart.com/ip/Lee-Women-s-Midrise-Straight-Leg-Jean/178550486?variantFieldId=actual_color"}
